# %%
# !pip install pymongo
# Out:
# ...
#    ---------------------------------------- 0.0/926.7 kB ? eta -:--:--
#    --------------------------------------- 926.7/926.7 kB 21.4 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
import pandas as pd

# %%
client = MongoClient('mongodb+srv://kaorat:kaorat@cluster0.6bukw.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')

# %%
research_col = client['db1']['visual_trend_data']

# %%
df = pd.read_csv("merged_trend_data.csv")

# %%
df
# Out:
#                                    Keyword  Year  Count
# 0                         Machine Learning  2018     25
# 1                         Machine Learning  2019     60
# 2                         Machine Learning  2020     90
# 3                         Machine Learning  2021    185
# 4                         Machine Learning  2022    197
# 5                         Machine Learning  2023    286
# 6                           Climate Change  2018      5
# 7                           Climate Change  2019     20
# 8                           Climate Change  2020     28
# 9                           Climate Change  2021     69
# 10                          Climate Change  2022     72
# 11                          Climate Change  2023    100
# 12                                COVID-19  2018      0
# 13                                COVID-19  2019      0
# 14                                COVID-19  2020     29
# 15                                COVID-19  2021     80
# ...

# %%
dic_lit = df.to_dict(orient='records')

# %%
len(dic_lit)
# Out:
# 36

# %%
research_col.insert_many(dic_lit)
# Out:
# InsertManyResult([ObjectId('67554adbeb5d0df312c93021'), ObjectId('67554adbeb5d0df312c93022'), ObjectId('67554adbeb5d0df312c93023'), ObjectId('67554adbeb5d0df312c93024'), ObjectId('67554adbeb5d0df312c93025'), ObjectId('67554adbeb5d0df312c93026'), ObjectId('67554adbeb5d0df312c93027'), ObjectId('67554adbeb5d0df312c93028'), ObjectId('67554adbeb5d0df312c93029'), ObjectId('67554adbeb5d0df312c9302a'), ObjectId('67554adbeb5d0df312c9302b'), ObjectId('67554adbeb5d0df312c9302c'), ObjectId('67554adbeb5d0df312c9302d'), ObjectId('67554adbeb5d0df312c9302e'), ObjectId('67554adbeb5d0df312c9302f'), ObjectId('67554adbeb5d0df312c93030'), ObjectId('67554adbeb5d0df312c93031'), ObjectId('67554adbeb5d0df312c93032'), ObjectId('67554adbeb5d0df312c93033'), ObjectId('67554adbeb5d0df312c93034'), ObjectId('67554adbeb5d0df312c93035'), ObjectId('67554adbeb5d0df312c93036'), ObjectId('67554adbeb5d0df312c93037'), ObjectId('67554adbeb5d0df312c93038'), ObjectId('67554adbeb5d0df312c93039'), ObjectId('67554adbeb5d0df312c9
# ...

# %%
data = research_col.find({})

# %%
data = list(data)

# %%
len(data)
# Out:
# 66

# %%
df_1 = pd.DataFrame(data)

# %%
df_1
# Out:
#                             _id  \
# 0      67553ddfeb5d0df312c8caf8
# 1      67553ddfeb5d0df312c8caf9
# 2      67553ddfeb5d0df312c8cafa
# 3      67553ddfeb5d0df312c8cafb
# 4      67553ddfeb5d0df312c8cafc
# ...                         ...
# 20211  675545cdeb5d0df312c919eb
# 20212  675545cdeb5d0df312c919ec
# 20213  675545cdeb5d0df312c919ed
# 20214  675545cdeb5d0df312c919ee
# 20215  675545cdeb5d0df312c919ef
#
#                                                    Title  ref_count  \
# 0      Public health and international epidemiology f...       76.0
# 1      Flexible Printed Active Antenna for Digital Te...        4.0
# 2      Parametric study of hydrogen production via so...       42.0
# 3      Superhydrophobic coating from fluoroalkylsilan...       45.0
# 4      Electrochemical impedance-based DNA sensor usi...       55.0
# ...                                                  ...        ...
# 20211  Long-chain bio-olefins production via oxidativ...       63.0
# ...
